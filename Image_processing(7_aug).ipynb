# %%
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread("00-puppy.jpg")
print(img)
# Out:
# [[[78 81 95]
#   [80 83 97]
#   [81 84 98]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  [[78 81 95]
#   [79 82 96]
#   [79 82 96]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  [[78 81 95]
#   [77 80 94]
#   [77 80 94]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  ...
#
#  [[20 29 19]
#   [21 30 20]
#   [21 30 20]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]
#
#  [[21 30 20]
#   [21 30 20]
#   [20 29 19]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]
#
#  [[21 30 20]
#   [20 29 19]
#   [20 29 19]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]]

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# Converting to HSV

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img=cv2.imread("00-puppy.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %% [markdown]
# Blending and Pasting images
#
# for some computer vision systems , we will want to be able to post our img on the top of the

# %%
import cv2

# %%
#two images 
img1=cv2.imread("dog_backpack.jpg")
img2=cv2.imread("watermark_no_copy.png")

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.3,gamma=0)

# %%
plt.imshow(blended)

# %% [markdown]
# Thresholding in image processing is a commonly used technique that involves converting an image into a binary image by seperating the pixels into two classes based on their intensity values. The process involves selecting a threshold value, which acts as a boundary between the two classes. Pixels with intensity values above the threshold are assigned one value, usually white, While those below the threshold are assigned  another value, usually black. thresholding is useul or a range of applications, including image segmentation, obj detection and img binarization , It is simple yet powerful technique that can help to simplify complex images and make them easier to analyze and process.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("rainbow.jpg")

# %%
plt.imshow(img)

# %%
#adding the 0 flag to read it in black and white
img=cv2.imread("rainbow.jpg",0)

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# Different Threshold types
#
# Binary

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %% [markdown]
# # Binary Inverse

# %%
ret,thresh2=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh2,cmap='gray')

# %%
ret,thresh3=cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
plt.imshow(thresh3,cmap='gray')

# %%
ret,thresh4=cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')
